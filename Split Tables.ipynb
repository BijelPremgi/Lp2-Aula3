# %%
import numpy as np
import pandas as pd

# %%
imdb_movies = pd.read_csv(r"IMDb movies.csv" , low_memory=False)

# %%
imdb_movies.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  ...  \
# 0     None                      Alexander Black  ...
# 1     None                         Charles Tait  ...
# 2      NaN                            Urban Gad  ...
# 3  English                   Charles L. Gaskill  ...
# 4  Italian  Francesco Bertolini, Adolfo Padovan  ...
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
#
#                                          description avg_vote votes   budget  \
# 0  The adventures of a female reporter in the 1890s.      5.9   154      NaN
# 1  True story of notorious Australian outlaw Ned ...      6.1   589   $ 2250
# 2  Two men of high rank are both wooing the beaut...      5.8   188      NaN
# 3  The fabled queen of Egypt's affair with Roman ...      5.2   446  $ 45000
# 4  Loosely adapted from Dante's Divine Comedy and...      7.0  2237      NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                1.0
# 1               NaN                   NaN       NaN                7.0
# 2               NaN                   NaN       NaN                5.0
# 3               NaN                   NaN       NaN               25.0
# 4               NaN                   NaN       NaN               31.0
#
#    reviews_from_critics
# 0                   2.0
# 1                   7.0
# 2                   2.0
# 3                   3.0
# 4                  14.0
#
# [5 rows x 22 columns]

# %% [markdown]
# # Languages Column
# 1. Dataframe with movie_id and language from imdb_movie -> movie_language (new df)
# 2. In movie_language, look ate the language column and split (','), put in variable 's' and line up with movie_genre indexes
# 3. Del the 'genre' column in movie_genre
# 4. Join 's' + movie_genre
# 5. Create languages table<br/>
#    5.1. Dataframe with langiages name from movie_language -> languages (new df)<br/>
#    5.2  Drop duplicates<br/>
#    5.3  Ad de ID column<br/>
# 6. Merge movie_language with languages
# 7. Rename columns
# 8. Drop language column in movie_language to have a  table with the movie_id and language_id
# 9. Drop language column in imdb_movies

# %%
movie_language = imdb_movies[['imdb_title_id','language']] #Dataframe with movie_id and language column

# %%
movie_language
# Out:
#       imdb_title_id       language
# 0         tt0000009           None
# 1         tt0000574           None
# 2         tt0001892            NaN
# 3         tt0002101        English
# 4         tt0002130        Italian
# ...             ...            ...
# 85850     tt9908390         French
# 85851     tt9911196  German, Dutch
# 85852     tt9911774      Malayalam
# 85853     tt9914286        Turkish
# 85854     tt9914942        Catalan
#
# [85855 rows x 2 columns]

# %%
s = movie_language['language'].str.split(',').apply(pd.Series, 1).stack() #split languages 
s.index = s.index.droplevel(-1)
s.name = 'language'
s
# Out:
# 0             None
# 1             None
# 3          English
# 4          Italian
# 5          English
#            ...
# 85851       German
# 85851        Dutch
# 85852    Malayalam
# 85853      Turkish
# 85854      Catalan
# Name: language, Length: 109221, dtype: object

# %%
#del movie_language['language'] #run only once

# %%
#movie_language = movie_language.join(s)
movie_language.head()
# Out:
#   imdb_title_id language
# 0     tt0000009     None
# 1     tt0000574     None
# 2     tt0001892      NaN
# 3     tt0002101  English
# 4     tt0002130  Italian

# %%
languages = movie_language[['language']]

# %%
languages = languages.dropna()

# %%
languages = languages.drop_duplicates()

# %%
languages
# Out:
#             language
# 0               None
# 3            English
# 4            Italian
# 6             German
# 10            Danish
# ...              ...
# 82070       Balinese
# 82329         Tswana
# 84353        Soninke
# 84913          Haida
# 85467  Crimean Tatar
#
# [421 rows x 1 columns]

# %%
languages.index = [x for x in range(1, len(languages.values)+1)] #redo the index

# %%
languages.index.name = 'Id' #rename
languages = languages.reset_index() #run only once
languages
# Out:
#       Id       language
# 0      1           None
# 1      2        English
# 2      3        Italian
# 3      4         German
# 4      5         Danish
# ..   ...            ...
# 416  417       Balinese
# 417  418         Tswana
# 418  419        Soninke
# 419  420          Haida
# 420  421  Crimean Tatar
#
# [421 rows x 2 columns]

# %%
languages = languages.rename(columns = {'language': 'name'})

# %%
languages
# Out:
#       Id           name
# 0      1           None
# 1      2        English
# 2      3        Italian
# 3      4         German
# 4      5         Danish
# ..   ...            ...
# 416  417       Balinese
# 417  418         Tswana
# 418  419        Soninke
# 419  420          Haida
# 420  421  Crimean Tatar
#
# [421 rows x 2 columns]

# %%
movie_language = pd.merge(movie_language, languages, how="left", on="language")

# %%
movie_language = movie_language.dropna()

# %%
movie_language.index = [x for x in range(1, len(movie_language.values)+1)]

# %%
movie_language = movie_language.rename(columns = {'imdb_title_id': 'movie_id', 'Id': 'language_id'})

# %%
del movie_language['language']

# %%
movie_language
# Out:
#          movie_id  language_id
# 1       tt0000009          1.0
# 2       tt0000574          1.0
# 3       tt0002101          2.0
# 4       tt0002130          3.0
# 5       tt0002199          2.0
# ...           ...          ...
# 109217  tt9911196          4.0
# 109218  tt9911196         68.0
# 109219  tt9911774        138.0
# 109220  tt9914286         53.0
# 109221  tt9914942        235.0
#
# [109221 rows x 2 columns]

# %%
del imdb_movies['language']

# %%
imdb_movies
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# 4                           L'Inferno  1911     1911-03-06
# ...                               ...   ...            ...
# 85850                         Le lion  2020     2020-01-29
# 85851  De Beentjes van Sint-Hildegard  2020     2020-02-13
# 85852       Padmavyuhathile Abhimanyu  2019     2019-03-08
# 85853               Sokagin Çocuklari  2019     2019-03-15
# 85854      La vida sense la Sara Amat  2019     2020-02-05
#
#                            genre  duration           country  \
# 0                        Romance        45               USA
# 1        Biography, Crime, Drama        70         Australia
# 2                          Drama        53  Germany, Denmark
# 3                 Drama, History       100               USA
# 4      Adventure, Drama, Fantasy        68             Italy
# ...                          ...       ...               ...
# 85850                     Comedy        95   France, Belgium
# 85851              Comedy, Drama       103       Netherlands
# 85852                      Drama       130             India
# 85853              Drama, Family        98            Turkey
# 85854                      Drama        74             Spain
#
#                                   director  \
# 0                          Alexander Black
# 1                             Charles Tait
# 2                                Urban Gad
# 3                       Charles L. Gaskill
# 4      Francesco Bertolini, Adolfo Padovan
# ...                                    ...
# 85850               Ludovic Colbeau-Justin
# 85851                      Johan Nijenhuis
# 85852                      Vineesh Aaradya
# 85853                    Ahmet Faik Akinci
# 85854                            Laura Jou
#
#                                       writer  ...  \
# 0                            Alexander Black  ...
# 1                               Charles Tait  ...
# 2      Urban Gad, Gebhard Schätzler-Perasini  ...
# 3                           Victorien Sardou  ...
# 4                            Dante Alighieri  ...
# ...                                      ...  ...
# 85850  Alexandre Coquelle, Matthieu Le Naour  ...
# 85851           Radek Bajgar, Herman Finkers  ...
# 85852       Vineesh Aaradya, Vineesh Aaradya  ...
# 85853         Ahmet Faik Akinci, Kasim Uçkan  ...
# 85854                   Coral Cruz, Pep Puig  ...
#
#                                                   actors  \
# 0      Blanche Bayliss, William Courtenay, Chauncey D...
# 1      Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2      Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3      Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4      Salvatore Papa, Arturo Pirovano, Giuseppe de L...
# ...                                                  ...
# 85850  Dany Boon, Philippe Katerine, Anne Serra, Samu...
# 85851  Herman Finkers, Johanna ter Steege, Leonie ter...
# 85852  Anoop Chandran, Indrans, Sona Nair, Simon Brit...
# 85853  Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...
# 85854  Maria Morera Colomer, Biel Rossell Pelfort, Is...
#
#                                              description avg_vote  votes  \
# 0      The adventures of a female reporter in the 1890s.      5.9    154
# 1      True story of notorious Australian outlaw Ned ...      6.1    589
# 2      Two men of high rank are both wooing the beaut...      5.8    188
# 3      The fabled queen of Egypt's affair with Roman ...      5.2    446
# 4      Loosely adapted from Dante's Divine Comedy and...      7.0   2237
# ...                                                  ...      ...    ...
# 85850  A psychiatric hospital patient pretends to be ...      5.3    398
# 85851  A middle-aged veterinary surgeon believes his ...      7.7    724
# 85852                                                NaN      7.9    265
# 85853                                                NaN      6.4    194
# 85854  Pep, a 13-year-old boy, is in love with a girl...      6.7    102
#
#         budget usa_gross_income worlwide_gross_income metascore  \
# 0          NaN              NaN                   NaN       NaN
# 1       $ 2250              NaN                   NaN       NaN
# 2          NaN              NaN                   NaN       NaN
# 3      $ 45000              NaN                   NaN       NaN
# 4          NaN              NaN                   NaN       NaN
# ...        ...              ...                   ...       ...
# 85850      NaN              NaN             $ 3507171       NaN
# 85851      NaN              NaN             $ 7299062       NaN
# 85852      NaN              NaN                   NaN       NaN
# 85853      NaN              NaN                $ 2833       NaN
# 85854      NaN              NaN               $ 59794       NaN
#
#        reviews_from_users  reviews_from_critics
# 0                     1.0                   2.0
# 1                     7.0                   7.0
# 2                     5.0                   2.0
# 3                    25.0                   3.0
# 4                    31.0                  14.0
# ...                   ...                   ...
# 85850                 NaN                   4.0
# 85851                 6.0                   4.0
# 85852                 NaN                   NaN
# 85853                 NaN                   NaN
# 85854                 NaN                   2.0
#
# [85855 rows x 21 columns]

# %% [markdown]
# # Genres Column
# 1. Dataframe with movie_id and genre from imdb_movie -> movie_genre (new df)
# 2. In movie_genre, look ate the genre column and split (','), put in variable 's' and line up with movie_genre indexes
# 3. Del the 'genre' column in movie_genre
# 4. Join 's' + movie_genre
# 5. Create genres table<br/>
#    5.1. Dataframe with genres_name from movie_genre -> genres (new df)<br/>
#    5.2  Drop duplicates<br/>
#    5.3  Ad de ID column<br/>
# 6. Merge movie_genre with genres
# 7. Rename columns
# 8. Drop genre column in movie_genre to have a  table with the movie_id and genre_id
# 9. Drop genre column in imdb_movies

# %%
imdb_movies.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
movie_genre = imdb_movies[['imdb_title_id', 'genre']]

# %%
movie_genre
# Out:
#       imdb_title_id                      genre
# 0         tt0000009                    Romance
# 1         tt0000574    Biography, Crime, Drama
# 2         tt0001892                      Drama
# 3         tt0002101             Drama, History
# 4         tt0002130  Adventure, Drama, Fantasy
# ...             ...                        ...
# 85850     tt9908390                     Comedy
# 85851     tt9911196              Comedy, Drama
# 85852     tt9911774                      Drama
# 85853     tt9914286              Drama, Family
# 85854     tt9914942                      Drama
#
# [85855 rows x 2 columns]

# %%
s = movie_genre['genre'].str.split(',').apply(pd.Series, 1).stack()
s.index = s.index.droplevel(-1)
s.name = 'genre'
s
# Out:
# 0          Romance
# 1        Biography
# 1            Crime
# 1            Drama
# 2            Drama
#            ...
# 85851        Drama
# 85852        Drama
# 85853        Drama
# 85853       Family
# 85854        Drama
# Name: language, Length: 175867, dtype: object

# %%
#Only run once to avoid errors
del movie_genre['genre']

# %%
movie_genre = movie_genre.join(s)

# %%
genres = movie_genre[['genre']]
genres = genres.drop_duplicates(subset=['genre'])
genres.index = [x for x in range(1, len(genres.values)+1)]
genres = genres.drop_duplicates(subset='genre', keep="last")
genres
# Out:
#           genre
# 1       Romance
# 2     Biography
# 3         Crime
# 4         Drama
# 5         Drama
# 6       History
# 7     Adventure
# 8       Fantasy
# 9       Romance
# 10      History
# 11          War
# 12        Crime
# 13      Mystery
# 14       Horror
# 15      Western
# 16      Fantasy
# 17       Comedy
# 18       Horror
# 19       Family
# 20    Adventure
# 21       Family
# 22       Action
# 23       Sci-Fi
# 24       Comedy
# 25      Western
# 26      Mystery
# 27     Thriller
# 28        Sport
# 29       Sci-Fi
# 30    Animation
# 31      Musical
# 32       Action
# 33        Music
# 34     Thriller
# 35    Film-Noir
# 36      Musical
# 37        Music
# 38    Biography
# 39          War
# 40    Film-Noir
# 41    Animation
# 42        Sport
# 43        Adult
# 44  Documentary
# 45   Reality-TV
# 46         News

# %%
genres = genres.drop_duplicates()
#genres
#genres = genres[['genre']] = genres[['genre']].astype(str)
#genres.dtypes
#print(genres.loc[genres['genre'] == ' Drama'])
genres['genre']  = genres['genre'].str.strip() #eleminate de white spaces

# %%
genres.index = [x for x in range(1, len(genres.values)+1)] #redo indexes

# %%
genres.index.name = 'Id' #rename
genres = genres.reset_index() #run only once

# %%
genres = genres.rename(columns = {'genre': 'name'})

# %%
genres
# Out:
#     Id         name
# 0    1      Romance
# 1    2    Biography
# 2    3        Crime
# 3    4        Drama
# 4    5      History
# 5    6    Adventure
# 6    7      Fantasy
# 7    8          War
# 8    9      Mystery
# 9   10       Horror
# 10  11      Western
# 11  12       Comedy
# 12  13       Family
# 13  14       Action
# 14  15       Sci-Fi
# 15  16     Thriller
# 16  17        Sport
# 17  18    Animation
# 18  19      Musical
# 19  20        Music
# 20  21    Film-Noir
# 21  22        Adult
# 22  23  Documentary
# 23  24   Reality-TV
# 24  25         News

# %%
movie_genre = pd.merge(movie_genre, genres, how="left", on="genre")

# %%
movie_genre = movie_genre.dropna()

# %%
movie_genre.index = [x for x in range(1, len(movie_genre.values)+1)]

# %%
movie_genre = movie_genre.rename(columns = {'imdb_title_id': 'movie_id', 'Id' : 'genre_id'})

# %%
del movie_genre['genre'] # run only once

# %%
movie_genre
# Out:
#         movie_id  genre_id
# 1      tt0000009       1.0
# 2      tt0000574       2.0
# 3      tt0001892       4.0
# 4      tt0002101       4.0
# 5      tt0002130       6.0
# ...          ...       ...
# 85851  tt9908390      12.0
# 85852  tt9911196      12.0
# 85853  tt9911774       4.0
# 85854  tt9914286       4.0
# 85855  tt9914942       4.0
#
# [85855 rows x 2 columns]

# %%
del imdb_movies['genre'] #run only  once

# %%
imdb_movies
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  duration  \
# 0                          Miss Jerry  1894     1894-10-09        45
# 1         The Story of the Kelly Gang  1906     1906-12-26        70
# 2                      Den sorte drøm  1911     1911-08-19        53
# 3                           Cleopatra  1912     1912-11-13       100
# 4                           L'Inferno  1911     1911-03-06        68
# ...                               ...   ...            ...       ...
# 85850                         Le lion  2020     2020-01-29        95
# 85851  De Beentjes van Sint-Hildegard  2020     2020-02-13       103
# 85852       Padmavyuhathile Abhimanyu  2019     2019-03-08       130
# 85853               Sokagin Çocuklari  2019     2019-03-15        98
# 85854      La vida sense la Sara Amat  2019     2020-02-05        74
#
#                 country                             director  \
# 0                   USA                      Alexander Black
# 1             Australia                         Charles Tait
# 2      Germany, Denmark                            Urban Gad
# 3                   USA                   Charles L. Gaskill
# 4                 Italy  Francesco Bertolini, Adolfo Padovan
# ...                 ...                                  ...
# 85850   France, Belgium               Ludovic Colbeau-Justin
# 85851       Netherlands                      Johan Nijenhuis
# 85852             India                      Vineesh Aaradya
# 85853            Turkey                    Ahmet Faik Akinci
# 85854             Spain                            Laura Jou
#
#                                       writer             production_company  \
# 0                            Alexander Black     Alexander Black Photoplays
# 1                               Charles Tait                 J. and N. Tait
# 2      Urban Gad, Gebhard Schätzler-Perasini                       Fotorama
# 3                           Victorien Sardou  Helen Gardner Picture Players
# 4                            Dante Alighieri                    Milano Film
# ...                                      ...                            ...
# 85850  Alexandre Coquelle, Matthieu Le Naour              Monkey Pack Films
# 85851           Radek Bajgar, Herman Finkers           Johan Nijenhuis & Co
# 85852       Vineesh Aaradya, Vineesh Aaradya               RMCC Productions
# 85853         Ahmet Faik Akinci, Kasim Uçkan                    Gizem Ajans
# 85854                   Coral Cruz, Pep Puig  La Xarxa de Comunicació Local
#
#                                                   actors  \
# 0      Blanche Bayliss, William Courtenay, Chauncey D...
# 1      Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2      Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3      Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4      Salvatore Papa, Arturo Pirovano, Giuseppe de L...
# ...                                                  ...
# 85850  Dany Boon, Philippe Katerine, Anne Serra, Samu...
# 85851  Herman Finkers, Johanna ter Steege, Leonie ter...
# 85852  Anoop Chandran, Indrans, Sona Nair, Simon Brit...
# 85853  Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...
# 85854  Maria Morera Colomer, Biel Rossell Pelfort, Is...
#
#                                              description  avg_vote  votes  \
# 0      The adventures of a female reporter in the 1890s.       5.9    154
# 1      True story of notorious Australian outlaw Ned ...       6.1    589
# 2      Two men of high rank are both wooing the beaut...       5.8    188
# 3      The fabled queen of Egypt's affair with Roman ...       5.2    446
# 4      Loosely adapted from Dante's Divine Comedy and...       7.0   2237
# ...                                                  ...       ...    ...
# 85850  A psychiatric hospital patient pretends to be ...       5.3    398
# 85851  A middle-aged veterinary surgeon believes his ...       7.7    724
# 85852                                                NaN       7.9    265
# 85853                                                NaN       6.4    194
# 85854  Pep, a 13-year-old boy, is in love with a girl...       6.7    102
#
#         budget usa_gross_income worlwide_gross_income  metascore  \
# 0          NaN              NaN                   NaN        NaN
# 1       $ 2250              NaN                   NaN        NaN
# 2          NaN              NaN                   NaN        NaN
# 3      $ 45000              NaN                   NaN        NaN
# 4          NaN              NaN                   NaN        NaN
# ...        ...              ...                   ...        ...
# 85850      NaN              NaN             $ 3507171        NaN
# 85851      NaN              NaN             $ 7299062        NaN
# 85852      NaN              NaN                   NaN        NaN
# 85853      NaN              NaN                $ 2833        NaN
# 85854      NaN              NaN               $ 59794        NaN
#
#        reviews_from_users  reviews_from_critics
# 0                     1.0                   2.0
# 1                     7.0                   7.0
# 2                     5.0                   2.0
# 3                    25.0                   3.0
# 4                    31.0                  14.0
# ...                   ...                   ...
# 85850                 NaN                   4.0
# 85851                 6.0                   4.0
# 85852                 NaN                   NaN
# 85853                 NaN                   NaN
# 85854                 NaN                   2.0
#
# [85855 rows x 20 columns]
